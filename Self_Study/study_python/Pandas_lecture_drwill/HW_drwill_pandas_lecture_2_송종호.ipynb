# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus']=False

# %% [markdown]
# # Reshaping Data
# - melt : 열을 행으로
# - df.pivot : 행을 열로
# - df.sort_values : 특정 열의 데이터를 기준으로 데이터프레임을 정렬
# - df.rename : 데이터프레임 내의 행, 열의 이름을 변경
# - df.sort_index : 인덱스 별로 정렬
# - df.reset_index : 인덱스가 없을 때, 인덱스를 생성해서 정렬
# - df.drop : 특정 컬럼 제거

# %%
df = sns.load_dataset('mpg')
df.shape # 데이터프레임 형성 확인
# Out:
# (398, 9)

# %%
df.head() # 첫 5줄 확인
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.sort_values('mpg').head() # mpg 컬럼을 오름차순으로 정렬 후 첫 5행 확인
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 28    9.0          8         304.0       193.0    4732          18.5
# 25   10.0          8         360.0       215.0    4615          14.0
# 26   10.0          8         307.0       200.0    4376          15.0
# 103  11.0          8         400.0       150.0    4997          14.0
# 124  11.0          8         350.0       180.0    3664          11.0
#
#      model_year origin              name
# 28           70    usa          hi 1200d
# 25           70    usa         ford f250
# 26           70    usa         chevy c20
# 103          73    usa  chevrolet impala
# 124          73    usa  oldsmobile omega

# %%
df.sort_values('cylinders').head() # cylinders 컬럼을 오름차순으로 정렬 후 첫 5행 확인
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 111  18.0          3          70.0        90.0    2124          13.5
# 71   19.0          3          70.0        97.0    2330          13.5
# 334  23.7          3          70.0       100.0    2420          12.5
# 243  21.5          3          80.0       110.0    2720          13.5
# 267  27.5          4         134.0        95.0    2560          14.2
#
#      model_year origin             name
# 111          73  japan        maxda rx3
# 71           72  japan  mazda rx2 coupe
# 334          80  japan    mazda rx-7 gs
# 243          77  japan       mazda rx-4
# 267          78  japan    toyota corona

# %%
df.sort_values('mpg', ascending=False).head() # mpg 컬럼을 내림차순으로 정렬 후 첫 5행 확인
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0        65.0    2110          17.9
# 329  44.6          4          91.0        67.0    1850          13.8
# 325  44.3          4          90.0        48.0    2085          21.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 326  43.4          4          90.0        48.0    2335          23.7
#
#      model_year  origin                  name
# 322          80   japan             mazda glc
# 329          80   japan   honda civic 1500 gl
# 325          80  europe  vw rabbit c (diesel)
# 394          82  europe             vw pickup
# 326          80  europe    vw dasher (diesel)

# %%
df.rename(columns = {'model_year':'year'}).head() # model_year 컬럼명을 year로 변경 후 5줄 확인
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#   origin                       name
# 0    usa  chevrolet chevelle malibu
# 1    usa          buick skylark 320
# 2    usa         plymouth satellite
# 3    usa              amc rebel sst
# 4    usa                ford torino

# %%
df.head() # 기존 데이터 프레임은 변경되지 않음
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df = df.rename(columns = {'model_year':'year'}).head() # 기존 데이터프레임을 변경
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#   origin                       name
# 0    usa  chevrolet chevelle malibu
# 1    usa          buick skylark 320
# 2    usa         plymouth satellite
# 3    usa              amc rebel sst
# 4    usa                ford torino

# %%
df.sort_index().head() # 인덱스를 기준으로 오름차순으로 정렬
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#   origin                       name
# 0    usa  chevrolet chevelle malibu
# 1    usa          buick skylark 320
# 2    usa         plymouth satellite
# 3    usa              amc rebel sst
# 4    usa                ford torino

# %%
df.reset_index() # 새로운 인덱스로 리셋
# Out:
#    index   mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0      0  18.0          8         307.0       130.0    3504          12.0
# 1      1  15.0          8         350.0       165.0    3693          11.5
# 2      2  18.0          8         318.0       150.0    3436          11.0
# 3      3  16.0          8         304.0       150.0    3433          12.0
# 4      4  17.0          8         302.0       140.0    3449          10.5
#
#    year origin                       name
# 0    70    usa  chevrolet chevelle malibu
# 1    70    usa          buick skylark 320
# 2    70    usa         plymouth satellite
# 3    70    usa              amc rebel sst
# 4    70    usa                ford torino

# %%
df2 = df.drop(columns=['mpg','year']) # mpg, year 컬럼만 제거
df2.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration origin  \
# 0          8         307.0       130.0    3504          12.0    usa
# 1          8         350.0       165.0    3693          11.5    usa
# 2          8         318.0       150.0    3436          11.0    usa
# 3          8         304.0       150.0    3433          12.0    usa
# 4          8         302.0       140.0    3449          10.5    usa
#
#                         name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
df3 = df.drop(columns=['mpg','year','name']) # mpg, year, name 컬럼만 제거
df3.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration origin
# 0          8         307.0       130.0    3504          12.0    usa
# 1          8         350.0       165.0    3693          11.5    usa
# 2          8         318.0       150.0    3436          11.0    usa
# 3          8         304.0       150.0    3433          12.0    usa
# 4          8         302.0       140.0    3449          10.5    usa

# %%
df = pd.DataFrame({'A':{0:'a',1:'b',2:'c'}, 'B':{0:1,1:3,2:5}, 'C':{0:2,1:4,2:6}})
df
# Out:
#    A  B  C
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6

# %%
pd.melt(df, id_vars=['A'], value_vars=['B'])
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5

# %%
df2 = pd.melt(df, id_vars=['A'], value_vars=['B','C'])
df2
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5
# 3  a        C      2
# 4  b        C      4
# 5  c        C      6

# %%
df3 = pd.melt(df, value_vars=['A','B','C'])
df3
# Out:
#   variable value
# 0        A     a
# 1        A     b
# 2        A     c
# 3        B     1
# 4        B     3
# 5        B     5
# 6        C     2
# 7        C     4
# 8        C     6

# %%
df3 = pd.melt(df, value_vars=['A','B','C']).rename(columns={'variable':'var','value':'val'})
df3
# Out:
#   var val
# 0   A   a
# 1   A   b
# 2   A   c
# 3   B   1
# 4   B   3
# 5   B   5
# 6   C   2
# 7   C   4
# 8   C   6

# %%
df4 = pd.DataFrame({'bar':['A','B','C','A','B','C'], 'baz':[1,2,3,4,5,6], 'foo':['one','one','one','two','two','two']})
df4
# Out:
#   bar  baz  foo
# 0   A    1  one
# 1   B    2  one
# 2   C    3  one
# 3   A    4  two
# 4   B    5  two
# 5   C    6  two

# %%
df4.pivot(index='foo',columns='bar',values='baz')
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %%
df4.pivot(index='foo',columns='bar',values='baz').reset_index()
# Out:
# bar  foo  A  B  C
# 0    one  1  2  3
# 1    two  4  5  6

# %%
df5 = df4.pivot(index='foo',columns='bar',values='baz').reset_index()

# %%
df5.melt(id_vars=['foo'],value_vars=['A','B','C'])
# Out:
#    foo bar  value
# 0  one   A      1
# 1  two   A      4
# 2  one   B      2
# 3  two   B      5
# 4  one   C      3
# 5  two   C      6

# %%
df5.melt(id_vars=['foo'],value_vars=['A','B','C']).sort_values(by=['bar'])
# Out:
#    foo bar  value
# 0  one   A      1
# 1  two   A      4
# 2  one   B      2
# 3  two   B      5
# 4  one   C      3
# 5  two   C      6

# %%
df5.melt(id_vars=['foo'],value_vars=['A','B','C']).sort_values(by=['foo'])
# Out:
#    foo bar  value
# 0  one   A      1
# 2  one   B      2
# 4  one   C      3
# 1  two   A      4
# 3  two   B      5
# 5  two   C      6

# %%
df5.melt(id_vars=['foo'],value_vars=['A','B','C']).sort_values(by=['foo','bar'])
# Out:
#    foo bar  value
# 0  one   A      1
# 2  one   B      2
# 4  one   C      3
# 1  two   A      4
# 3  two   B      5
# 5  two   C      6

# %%
df5.melt(id_vars=['foo'],value_vars=['A','B','C']).sort_values(by=['foo','bar']).rename(columns={'value':'baz'})
# Out:
#    foo bar  baz
# 0  one   A    1
# 2  one   B    2
# 4  one   C    3
# 1  two   A    4
# 3  two   B    5
# 5  two   C    6

# %% [markdown]
# # 데이터프레임 합치기
# - pd.concat : 행으로(axis=0), 열로(axis=1) 데이터프레임 결합

# %%
s1 = pd.Series(['a','b'])
s1
# Out:
# 0    a
# 1    b
# dtype: object

# %%
s2 = pd.Series(['c','d'])
s2
# Out:
# 0    c
# 1    d
# dtype: object

# %%
pd.concat([s1,s2])
# Out:
# 0    a
# 1    b
# 0    c
# 1    d
# dtype: object

# %%
pd.concat([s1,s2], keys=['s1','s2'])
# Out:
# s1  0    a
#     1    b
# s2  0    c
#     1    d
# dtype: object

# %%
pd.concat([s1,s2], keys=['s1','s2'], names=['Series name','Row ID'])
# Out:
# Series name  Row ID
# s1           0         a
#              1         b
# s2           0         c
#              1         d
# dtype: object

# %%
df1 = pd.DataFrame([['a',1],['b',2]],columns=['letter','number'])
df1
# Out:
#   letter  number
# 0      a       1
# 1      b       2

# %%
df2 = pd.DataFrame([['c',3],['d',4]],columns=['letter','number'])
df2
# Out:
#   letter  number
# 0      c       3
# 1      d       4

# %%
pd.concat([df1,df2])
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %%
df3 = pd.DataFrame([['c',3,'cat'],['d',4,'dof']],columns=['letter','number','animal'])
df3
# Out:
#   letter  number animal
# 0      c       3    cat
# 1      d       4    dof

# %%
pd.concat([df1,df3])
# Out:
#   letter  number animal
# 0      a       1    NaN
# 1      b       2    NaN
# 0      c       3    cat
# 1      d       4    dof

# %%
pd.concat([df1,df3], join='inner') # 두 데이터프레임에 모두 있는 컬럼에 대해서만
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %%
pd.concat([df1,df3], sort=False)
# Out:
#   letter  number animal
# 0      a       1    NaN
# 1      b       2    NaN
# 0      c       3    cat
# 1      d       4    dof

# %%
df4 = pd.DataFrame([['bird','polly'],['monkey','george']],columns=['animal','name'])
df4
# Out:
#    animal    name
# 0    bird   polly
# 1  monkey  george

# %%
df5 = pd.DataFrame([1],index=['a'])
df5
# Out:
#    0
# a  1

# %%
df6 = pd.DataFrame([2],index=['a'])
df6
# Out:
#    0
# a  2

# %%
pd.concat([df5,df6],verify_integrity=True) # 합치고나서 인덱스가 중복되면 valueerror
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12656/2911443589.py in <module>
# ----> 1 pd.concat([df5,df6],verify_integrity=True) # 합치고나서 인덱스가 중복되는지
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
#     295         objs,
#     296         axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     477         self.copy = copy
#     478
# --> 479         self.new_axes = self._get_new_axes()
#     480
#     481     def get_result(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in _get_new_axes(self)
#     547     def _get_new_axes(self) -> list[Index]:
#     548         ndim = self._get_result_dim()
# --> 549         return [
#     550             self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     551             for i in range(ndim)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in <listcomp>(.0)
#     548         ndim = self._get_result_dim()
#     549         return [
# --> 550             self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     551             for i in range(ndim)
#     552         ]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in _get_concat_axis(self)
#     609             )
#     610
# --> 611         self._maybe_check_integrity(concat_axis)
#     612
#     613         return concat_axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in _maybe_check_integrity(self, concat_index)
#     617             if not concat_index.is_unique:
#     618                 overlap = concat_index[concat_index.duplicated()].unique()
# --> 619                 raise ValueError(f"Indexes have overlapping values: {overlap}")
#     620
#     621
#
# ValueError: Indexes have overlapping values: Index(['a'], dtype='object')

# %% [markdown]
# - merge : 기준에 따라 데이터프레임 병합
#     - how=inner : 동시에 존재하는 것만
#     - how=left : 동시에 존재하고 왼쪽 기준
#     - how=right : 동시에 존재하고 오른쪽 기준
#     - how=outer : 모든 값으로
#     - on : 기준이 되어줄 key

# %%
adf = pd.DataFrame({'x1':['A','B','C'],'x2':[1,2,3]})
adf
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3

# %%
bdf = pd.DataFrame({'x1':['A','B','D'],'x2':['T','F','T']})
bdf
# Out:
#   x1 x2
# 0  A  T
# 1  B  F
# 2  D  T

# %%
pd.merge(adf,bdf, how='left', on='x1')
# Out:
#   x1  x2_x x2_y
# 0  A     1    T
# 1  B     2    F
# 2  C     3  NaN

# %%
pd.merge(adf,bdf, how='right', on='x1')
# Out:
#   x1  x2_x x2_y
# 0  A   1.0    T
# 1  B   2.0    F
# 2  D   NaN    T

# %%
pd.merge(adf,bdf, how='inner', on='x1')
# Out:
#   x1  x2_x x2_y
# 0  A     1    T
# 1  B     2    F

# %%
pd.merge(adf,bdf, how='outer', on='x1')
# Out:
#   x1  x2_x x2_y
# 0  A   1.0    T
# 1  B   2.0    F
# 2  C   3.0  NaN
# 3  D   NaN    T

# %%
adf.x1
# Out:
# 0    A
# 1    B
# 2    C
# Name: x1, dtype: object

# %%
bdf.x1
# Out:
# 0    A
# 1    B
# 2    D
# Name: x1, dtype: object

# %%
adf.x1.isin(bdf.x1)
# Out:
# 0     True
# 1     True
# 2    False
# Name: x1, dtype: bool

# %%
adf[adf.x1.isin(bdf.x1)]
# Out:
#   x1  x2
# 0  A   1
# 1  B   2

# %%
adf[~adf.x1.isin(bdf.x1)]
# Out:
#   x1  x2
# 2  C   3

# %%
ydf = pd.DataFrame({'x1':['A','B','C'],'x2':[1,2,3]})
ydf
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3

# %%
zdf = pd.DataFrame({'x1':['B','C','D'],'x2':[2,3,4]})
zdf
# Out:
#   x1  x2
# 0  B   2
# 1  C   3
# 2  D   4

# %%
pd.merge(ydf,zdf)
# Out:
#   x1  x2
# 0  B   2
# 1  C   3

# %%
pd.merge(ydf,zdf, how='outer')
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3
# 3  D   4

# %%
pd.merge(ydf,zdf, how='outer', indicator=True) # 어떻게 병합되었는지 컬럼이 추가
# Out:
#   x1  x2      _merge
# 0  A   1   left_only
# 1  B   2        both
# 2  C   3        both
# 3  D   4  right_only

# %%
pd.merge(ydf,zdf, how='outer', indicator=True).query('_merge=="left_only"') # 요청한 값만 가지고 옴
# Out:
#   x1  x2     _merge
# 0  A   1  left_only

# %%
pd.merge(ydf,zdf, how='outer', indicator=True).query('_merge=="left_only"').drop(columns = ['_merge'])
# Out:
#   x1  x2
# 0  A   1

# %% [markdown]
# # 데이터 집계 활용
# - df.groupby
#     - df.groupby().size() : 특정 값의 크기를 보고 싶을때
#     - df.groupby().mean() : 특정 값의 평균을 보고 싶을때
# - shift()
#     - df.shift(1) : 아래 방향으로 1 행씩 이동
#     - df.shift(-1) : 위 방향으로 1 행씩 이동

# %%
df = sns.load_dataset('mpg')
df.head(3)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite

# %%
df.groupby(by='origin').size()
# Out:
# origin
# europe     70
# japan      79
# usa       249
# dtype: int64

# %%
df['origin'].value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
df.groupby(by='origin').min()
# Out:
#          mpg  cylinders  displacement  horsepower  weight  acceleration  \
# origin
# europe  16.2          4          68.0        46.0    1825          12.2
# japan   18.0          3          70.0        52.0    1613          11.4
# usa      9.0          4          85.0        52.0    1800           8.0
#
#         model_year                     name
# origin
# europe          70              audi 100 ls
# japan           70              datsun 1200
# usa             70  amc ambassador brougham

# %%
df.groupby(by='origin').max()
# Out:
#          mpg  cylinders  displacement  horsepower  weight  acceleration  \
# origin
# europe  44.3          6         183.0       133.0    3820          24.8
# japan   46.6          6         168.0       132.0    2930          21.0
# usa     39.0          8         455.0       230.0    5140          22.2
#
#         model_year                         name
# origin
# europe          82             vw rabbit custom
# japan           82  toyouta corona mark ii (sw)
# usa             82           pontiac ventura sj

# %%
df.groupby(by='origin').mean()
# Out:
#               mpg  cylinders  displacement  horsepower       weight  \
# origin
# europe  27.891429   4.157143    109.142857   80.558824  2423.300000
# japan   30.450633   4.101266    102.708861   79.835443  2221.227848
# usa     20.083534   6.248996    245.901606  119.048980  3361.931727
#
#         acceleration  model_year
# origin
# europe     16.787143   75.814286
# japan      16.172152   77.443038
# usa        15.033735   75.610442

# %%
df.groupby(by='origin')['cylinders'].size()
# Out:
# origin
# europe     70
# japan      79
# usa       249
# Name: cylinders, dtype: int64

# %%
df.groupby(by='origin')['cylinders'].mean()
# Out:
# origin
# europe    4.157143
# japan     4.101266
# usa       6.248996
# Name: cylinders, dtype: float64

# %%
df.groupby(by='origin')['cylinders'].median()
# Out:
# origin
# europe    4.0
# japan     4.0
# usa       6.0
# Name: cylinders, dtype: float64

# %%
df.groupby(by=['model_year','origin'])['cylinders'].mean()
# Out:
# model_year  origin
# 70          europe    4.000000
#             japan     4.000000
#             usa       7.636364
# 71          europe    4.000000
#             japan     4.000000
#             usa       6.200000
# 72          europe    4.000000
#             japan     3.800000
#             usa       6.888889
# 73          europe    4.000000
#             japan     4.250000
#             usa       7.241379
# 74          europe    4.000000
#             japan     4.000000
#             usa       6.266667
# 75          europe    4.000000
#             japan     4.000000
#             usa       6.400000
# 76          europe    4.250000
#             japan     4.500000
#             usa       6.363636
# 77          europe    4.000000
#             japan     4.166667
#             usa       6.222222
# 78          europe    4.833333
#             japan     4.000000
#             usa       6.000000
# 79          europe    4.250000
#             japan     4.000000
#             usa       6.260870
# 80          europe    4.111111
#             japan     4.076923
#             usa       4.285714
# 81          europe    4.500000
#             japan     4.333333
#             usa       4.923077
# 82          europe    4.000000
#             japan     4.000000
#             usa       4.300000
# Name: cylinders, dtype: float64

# %%
pd.DataFrame(df.groupby(by=['model_year','origin'])['cylinders'].mean())
# Out:
#                    cylinders
# model_year origin
# 70         europe   4.000000
#            japan    4.000000
#            usa      7.636364
# 71         europe   4.000000
#            japan    4.000000
#            usa      6.200000
# 72         europe   4.000000
#            japan    3.800000
#            usa      6.888889
# 73         europe   4.000000
#            japan    4.250000
#            usa      7.241379
# 74         europe   4.000000
#            japan    4.000000
#            usa      6.266667
# 75         europe   4.000000
#            japan    4.000000
#            usa      6.400000
# 76         europe   4.250000
#            japan    4.500000
#            usa      6.363636
# 77         europe   4.000000
#            japan    4.166667
#            usa      6.222222
# 78         europe   4.833333
#            japan    4.000000
#            usa      6.000000
# 79         europe   4.250000
#            japan    4.000000
#            usa      6.260870
# 80         europe   4.111111
#            japan    4.076923
#            usa      4.285714
# 81         europe   4.500000
#            japan    4.333333
#            usa      4.923077
# 82         europe   4.000000
#            japan    4.000000
#            usa      4.300000

# %%
df2 = pd.DataFrame([[4,7,10],[5,11,8],[6,9,12]],index=[1,2,3],columns=['a','b','c'])
df2
# Out:
#    a   b   c
# 1  4   7  10
# 2  5  11   8
# 3  6   9  12

# %%
df2.shift(1)
# Out:
#      a     b     c
# 1  NaN   NaN   NaN
# 2  4.0   7.0  10.0
# 3  5.0  11.0   8.0

# %%
df2.shift(-1)
# Out:
#      a     b     c
# 1  5.0  11.0   8.0
# 2  6.0   9.0  12.0
# 3  NaN   NaN   NaN

# %%
df2['b'].shift(-1)
# Out:
# 1    11.0
# 2     9.0
# 3     NaN
# Name: b, dtype: float64

# %%
df2['b'].shift(2)
# Out:
# 1    NaN
# 2    NaN
# 3    7.0
# Name: b, dtype: float64

# %%
df['model_year'].rank(method='min') # 순위를 매기되, 동점자는 최소를 기준으로
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
#        ...
# 393    368.0
# 394    368.0
# 395    368.0
# 396    368.0
# 397    368.0
# Name: model_year, Length: 398, dtype: float64

# %%
df['model_year'].rank(method='min').value_counts()
# Out:
# 86.0     40
# 245.0    36
# 183.0    34
# 368.0    31
# 153.0    30
# 1.0      29
# 281.0    29
# 310.0    29
# 339.0    29
# 30.0     28
# 58.0     28
# 217.0    28
# 126.0    27
# Name: model_year, dtype: int64

# %%
df['model_year'].rank(method='max') # 동점자는 최대를 기준으로
# Out:
# 0       29.0
# 1       29.0
# 2       29.0
# 3       29.0
# 4       29.0
#        ...
# 393    398.0
# 394    398.0
# 395    398.0
# 396    398.0
# 397    398.0
# Name: model_year, Length: 398, dtype: float64

# %%
df['model_year'].rank(pct=True) # 등수가 아니라 비율로
# Out:
# 0      0.037688
# 1      0.037688
# 2      0.037688
# 3      0.037688
# 4      0.037688
#          ...
# 393    0.962312
# 394    0.962312
# 395    0.962312
# 396    0.962312
# 397    0.962312
# Name: model_year, Length: 398, dtype: float64

# %%
df['model_year'].rank(method='first').head() # 동점자는 먼저나오면 더 위
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# Name: model_year, dtype: float64

# %%
df2
# Out:
#    a   b   c
# 1  4   7  10
# 2  5  11   8
# 3  6   9  12

# %%
df2.cumsum()
# Out:
#     a   b   c
# 1   4   7  10
# 2   9  18  18
# 3  15  27  30

# %%
df2.cummax()
# Out:
#    a   b   c
# 1  4   7  10
# 2  5  11  10
# 3  6  11  12

# %%
df2.cummin()
# Out:
#    a  b   c
# 1  4  7  10
# 2  4  7   8
# 3  4  7   8

# %%
df2.cumprod()
# Out:
#      a    b    c
# 1    4    7   10
# 2   20   77   80
# 3  120  693  960

# %% [markdown]
# # expanding & rolling
# - expanding : 요약 기능을 허용하는 확장 개체를 누적 적용하여 반환
# - rolling : 요약 기능을 허용하는 롤링 객체를 길이 n개의 창에 적용하여 반환, 이동평균을 구할 때 사용

# %%
s = pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2015',periods=1000))
s.plot()
# Out:
# <AxesSubplot:>

# %%
s = s.cumsum()
s.plot()
# Out:
# <AxesSubplot:>

# %%
r = s.rolling(window=30)
r
# Out:
# Rolling [window=30,center=False,axis=0,method=single]

# %%
r.mean()
# Out:
# 2015-01-01         NaN
# 2015-01-02         NaN
# 2015-01-03         NaN
# 2015-01-04         NaN
# 2015-01-05         NaN
#                 ...
# 2017-09-22   -5.104338
# 2017-09-23   -5.044866
# 2017-09-24   -4.940493
# 2017-09-25   -4.795656
# 2017-09-26   -4.595684
# Freq: D, Length: 1000, dtype: float64

# %%
s.plot(style='b--')
# Out:
# <AxesSubplot:>

# %%
r.mean().plot(style='r')
# Out:
# <AxesSubplot:>

# %%
s.plot(style='b--')
r.mean().plot(style='r')
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000,4),index=pd.date_range('1/1/2015',periods=1000),columns=['A','B','C','D'])
df.cumsum()
df
# Out:
#                    A         B         C         D
# 2015-01-01  1.345086 -0.391229  0.413058 -0.510977
# 2015-01-02  0.588356 -2.009917  0.030203 -0.350390
# 2015-01-03  0.610011  0.816795  0.939084  0.376459
# 2015-01-04  0.249777  0.860343  0.644409  1.403576
# 2015-01-05  1.370398 -0.096621 -1.271998 -1.024692
# ...              ...       ...       ...       ...
# 2017-09-22 -0.520622  1.728283  0.658354  0.736558
# 2017-09-23  0.361396  0.219454  0.018122 -0.898805
# 2017-09-24  0.213911  0.398926 -0.878783  1.503365
# 2017-09-25 -1.243404  0.319450  2.193550 -2.403805
# 2017-09-26 -1.590032  0.658891  0.937054  1.740070
#
# [1000 rows x 4 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.rolling(window=60).sum().plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
df.rolling(window=len(df),min_periods=1).mean().plot() # 데이터가 1개더라도 평균을 냄
# Out:
# <AxesSubplot:>

# %%
df.expanding(min_periods=1).mean()
# Out:
#                    A         B         C         D
# 2015-01-01  0.388674 -0.688685 -2.065433  1.094118
# 2015-01-02  0.166681 -0.241075 -1.085619  0.118947
# 2015-01-03  0.499706 -0.065515 -1.105304 -0.052369
# 2015-01-04  0.022555  0.042243 -0.553796 -0.273352
# 2015-01-05 -0.025512  0.427917 -0.442384 -0.133749
# ...              ...       ...       ...       ...
# 2017-09-22  0.007499 -0.000031 -0.030330 -0.003363
# 2017-09-23  0.007767 -0.001202 -0.028842 -0.002784
# 2017-09-24  0.008760 -0.000315 -0.027606 -0.003237
# 2017-09-25  0.008223  0.000653 -0.028117 -0.004622
# 2017-09-26  0.007690  0.001902 -0.027853 -0.005366
#
# [1000 rows x 4 columns]

# %%
df.expanding(min_periods=1).mean().plot()
# Out:
# <AxesSubplot:>

# %%
dfe = pd.DataFrame({'B':[0,1,2,np.nan,4]})
dfe
# Out:
#      B
# 0  0.0
# 1  1.0
# 2  2.0
# 3  NaN
# 4  4.0

# %%
dfe.plot()
# Out:
# <AxesSubplot:>

# %%
dfe.expanding(2).sum()
# Out:
#      B
# 0  NaN
# 1  1.0
# 2  3.0
# 3  3.0
# 4  7.0

# %%
dfe.expanding(2).sum().plot()
# Out:
# <AxesSubplot:>

# %%
dfe.expanding(2).mean().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 데이터 시각화
# - plot
#     - line : default, 선
#     - bar : 막대
#     - barh : 수평막대
#     - hist : 히스토그램
#     - box : 박스플롯
#     - kde : kernel density estimation
#     - density : kde와 동일
#     - area : 면적
#     - pie : 파이차트
#     - scatter : 산점도
#     - hexbin : hexbin plot

# %%
ts = pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2000', periods=1000))
ts.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000,4),index=ts.index, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2000-01-01 -1.715355 -0.262920  0.355691  0.351280
# 2000-01-02 -0.440501  1.002749  0.066619 -1.288754
# 2000-01-03 -1.195866  0.429197 -0.526782 -0.695031
# 2000-01-04 -0.735392 -0.995136 -0.935260 -0.525800
# 2000-01-05  0.532099 -1.151308  1.127595 -1.246770
# ...              ...       ...       ...       ...
# 2002-09-22 -0.587258 -1.148182  0.279962 -0.622963
# 2002-09-23 -0.963896 -0.249992 -0.257691 -1.509819
# 2002-09-24 -0.278210 -0.561864  0.116061 -0.469967
# 2002-09-25  1.109110 -0.691064 -2.042903 -1.030985
# 2002-09-26 -0.798135 -0.572418  0.361479  0.943486
#
# [1000 rows x 4 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
df3 = pd.DataFrame(np.random.randn(1000,2), columns=['B','C']).cumsum()
df3.head()
# Out:
#           B         C
# 0  0.809021  0.546239
# 1  1.314891 -1.006020
# 2  1.263425 -0.637212
# 3  1.833468 -1.580650
# 4  1.357508 -0.188597

# %%
df3['A']=pd.Series(list(range(len(df))))
df3.head()
# Out:
#           B         C  A
# 0  0.809021  0.546239  0
# 1  1.314891 -1.006020  1
# 2  1.263425 -0.637212  2
# 3  1.833468 -1.580650  3
# 4  1.357508 -0.188597  4

# %%
df3.plot(x='A', y='B')
# Out:
# <AxesSubplot:xlabel='A'>

# %% [markdown]
# - 막대그래프

# %%
ts.head()
# Out:
# 2000-01-01    2.222720
# 2000-01-02    1.861594
# 2000-01-03   -0.397008
# 2000-01-04   -2.182146
# 2000-01-05   -2.736094
# Freq: D, dtype: float64

# %%
df.head()
# Out:
#                    A         B         C         D
# 2000-01-01 -1.715355 -0.262920  0.355691  0.351280
# 2000-01-02 -0.440501  1.002749  0.066619 -1.288754
# 2000-01-03 -1.195866  0.429197 -0.526782 -0.695031
# 2000-01-04 -0.735392 -0.995136 -0.935260 -0.525800
# 2000-01-05  0.532099 -1.151308  1.127595 -1.246770

# %%
df.tail(2)
# Out:
#                    A         B         C         D
# 2002-09-25  1.109110 -0.691064 -2.042903 -1.030985
# 2002-09-26 -0.798135 -0.572418  0.361479  0.943486

# %%
df.iloc[5]
# Out:
# A   -0.079374
# B   -0.913872
# C    0.951231
# D   -0.210356
# Name: 2000-01-06 00:00:00, dtype: float64

# %%
df.iloc[5].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.iloc[5].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2 = pd.DataFrame(np.random.rand(10,4), columns=['a','b','c','d'])
df2.head()
# Out:
#           a         b         c         d
# 0  0.946448  0.879542  0.332961  0.519389
# 1  0.850244  0.767523  0.973405  0.144606
# 2  0.478027  0.045607  0.764574  0.626445
# 3  0.944226  0.856419  0.450899  0.725332
# 4  0.242277  0.589299  0.906847  0.940124

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df2.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - 히스토그램

# %%
df4 = pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':np.random.randn(1000)-1},columns=['a','b','c'])
df4.head()
# Out:
#           a         b         c
# 0  1.720498 -0.104631 -0.371913
# 1  0.504673 -1.044919  0.577334
# 2  1.063288 -0.265462  0.080604
# 3  0.474460  0.189658 -0.570210
# 4  1.317997  0.380233 -0.584291

# %%
df4.plot.hist(alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4.plot.hist(stacked=True,bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4['a'].plot.hist(orientation='horizontal', cumulative=True)
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df4['a'].diff().hist()
# Out:
# <AxesSubplot:>

# %%
df4['a_diff']=df4['a'].diff()
df4[['a','a_diff']]
# Out:
#             a    a_diff
# 0    1.720498       NaN
# 1    0.504673 -1.215825
# 2    1.063288  0.558615
# 3    0.474460 -0.588828
# 4    1.317997  0.843537
# ..        ...       ...
# 995  1.739642  0.273252
# 996  0.815540 -0.924102
# 997  0.927985  0.112444
# 998  0.626140 -0.301845
# 999  1.479608  0.853468
#
# [1000 rows x 2 columns]

# %%
df4['a_shift'] = df4['a'].shift(1)
df4['a_minus'] = df4['a']-df4['a_shift']
df4[['a','a_diff','a_shift','a_minus']].head()
# Out:
#           a    a_diff   a_shift   a_minus
# 0  1.720498       NaN       NaN       NaN
# 1  0.504673 -1.215825  1.720498 -1.215825
# 2  1.063288  0.558615  0.504673  0.558615
# 3  0.474460 -0.588828  1.063288 -0.588828
# 4  1.317997  0.843537  0.474460  0.843537

# %%
df4[['a','b','c']].diff().hist(color='k',alpha=0.5,bins=30)
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>, <AxesSubplot:>]], dtype=object)

# %%
data = pd.Series(np.random.randn(1000))

# %%
data.hist(by=np.random.randint(0,4,1000), figsize=(6,4))
# Out:
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %%
data = pd.DataFrame({'a':np.random.randn(1000),'b':np.random.randint(0,4,1000)})
data.head()
# Out:
#           a  b
# 0 -0.679256  1
# 1 -0.653552  0
# 2 -0.688108  1
# 3  1.177902  3
# 4 -0.235652  0

# %%
data['a'].hist(by=data['b'],figsize=(6,4))
# Out:
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %% [markdown]
# - 박스플롯

# %%
df = pd.DataFrame(np.random.rand(10,5),columns=['A','B','C','D','E'])
df.head()
# Out:
#           A         B         C         D         E
# 0  0.613442  0.538689  0.987527  0.577622  0.373034
# 1  0.689916  0.763281  0.829168  0.500916  0.995250
# 2  0.921429  0.913640  0.984577  0.993568  0.381425
# 3  0.510433  0.536407  0.339037  0.181155  0.736615
# 4  0.876884  0.284816  0.041071  0.675653  0.747909

# %%
df.describe()
# Out:
#                A          B          C          D          E
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.616457   0.522877   0.501465   0.528811   0.596755
# std     0.221829   0.250293   0.341625   0.308941   0.279977
# min     0.269188   0.150293   0.041071   0.070889   0.144059
# 25%     0.499163   0.327739   0.257404   0.261095   0.389259
# 50%     0.580664   0.537548   0.441378   0.578968   0.590069
# 75%     0.825287   0.717235   0.766162   0.657753   0.832003
# max     0.921429   0.913640   0.987527   0.993568   0.995250

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
color = {'boxes':'DarkGreen','whiskers':'DarkOrange','medians':'DarkBlue','caps':'Gray'}
df.plot.box(color=color, sym='r+')
# Out:
# <AxesSubplot:>

# %%
df.plot.box(vert=False,positions=[1,4,5,6,8])
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(10,5))
df.head(1)
# Out:
#          0         1         2         3         4
# 0  0.55458  0.549818  0.775776  0.273629  0.269111

# %%
bp = df.boxplot()

# %%
df = pd.DataFrame(np.random.rand(10,2), columns=['Col1','Col2'])
df.head(2)
# Out:
#        Col1      Col2
# 0  0.444752  0.126642
# 1  0.582649  0.165648

# %%
df['X'] = pd.Series(['A','A','A','A','A','B','B','B','B','B'])
df.head(2)
# Out:
#        Col1      Col2  X
# 0  0.444752  0.126642  A
# 1  0.582649  0.165648  A

# %%
bp = df.boxplot(by='X')

# %%
np.random.seed(1234)
df_box = pd.DataFrame(np.random.randn(50,2))
df_box.head()
# Out:
#           0         1
# 0  0.471435 -1.190976
# 1  1.432707 -0.312652
# 2 -0.720589  0.887163
# 3  0.859588 -0.636524
# 4  0.015696 -2.242685

# %%
df_box['g'] = np.random.choice(['A','B'],size=50)
df_box['g'].head()
# Out:
# 0    A
# 1    A
# 2    B
# 3    A
# 4    B
# Name: g, dtype: object

# %%
df_box.loc[df_box['g']=='B',1] +=3 # g컬럼이 B인 경우, 두번째 컬럼에 3을 더함

# %%
df_box.boxplot(by='g')
# Out:
# array([<AxesSubplot:title={'center':'0'}, xlabel='[g]'>,
#        <AxesSubplot:title={'center':'1'}, xlabel='[g]'>], dtype=object)

# %%
bp = df_box.boxplot(by='g')

# %%
bp = df_box.groupby('g').boxplot()

# %% [markdown]
# - 면적 그래프

# %%
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.head()
# Out:
#           a         b         c         d
# 0  0.108311  0.776181  0.782478  0.761604
# 1  0.914403  0.658623  0.568368  0.201756
# 2  0.698296  0.952195  0.889963  0.993567
# 3  0.818704  0.545122  0.451254  0.890557
# 4  0.973265  0.593411  0.366074  0.323095

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(grid=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.area(grid=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.area(stacked=False,grid=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - 산점도

# %%
df = pd.DataFrame(np.random.rand(50,4),columns=['a','b','c','d'])
df.head()
# Out:
#           a         b         c         d
# 0  0.737086  0.127029  0.369650  0.604334
# 1  0.103104  0.802374  0.945553  0.979039
# 2  0.881232  0.627682  0.930487  0.724790
# 3  0.716678  0.041079  0.439482  0.282070
# 4  0.334996  0.083527  0.760849  0.509272

# %%
df.plot.scatter(x='a',y='b',s=30,grid=True)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
ax = df.plot.scatter(x='a',y='b',color='DarkRed',label='Group 1')
df.plot.scatter(x='c',y='d',color='DarkGreen',label='Group 2', ax=ax)
# Out:
# <AxesSubplot:xlabel='c', ylabel='d'>

# %%
df.plot.scatter(x='a',y='b',c='c',s=100)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.scatter(x='a',y='b',s=df['c'])
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.scatter(x='a',y='b',s=df['c']*200)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# - hexbin

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])
df['b'] = df['b'] + np.arange(1000)
df['b']
# Out:
# 0        0.461659
# 1       -0.316938
# 2        2.528290
# 3        1.918991
# 4        2.298052
#           ...
# 995    996.203948
# 996    996.586199
# 997    998.381990
# 998    997.698713
# 999    999.424658
# Name: b, Length: 1000, dtype: float64

# %%
df.plot.hexbin(x='a',y='b',gridsize=10)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a',y='b',gridsize=5)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df['z'] = np.random.uniform(0,3,1000)
df['z']
# Out:
# 0      0.961631
# 1      2.198610
# 2      1.750773
# 3      0.137981
# 4      0.817960
#          ...
# 995    1.034762
# 996    0.228865
# 997    2.799262
# 998    0.217145
# 999    2.294694
# Name: z, Length: 1000, dtype: float64

# %%
df.plot.hexbin(x='a',y='b', C='z', reduce_C_function=np.max, gridsize=20)
# 점의 위치는 a와 b 컬럼으로
# 값은 z 컬럼으로
# reduce_C_function은 모든 값을 단일 숫자로 줄이는 하나의 인수의 함수
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a',y='b', C='z', reduce_C_function=np.median, gridsize=50)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a',y='b', C='z', reduce_C_function=np.mean, gridsize=50)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# - 파이차트

# %%
series = pd.Series(np.random.rand(4), index= ['a','b','c','d'], name='series')
series
# Out:
# a    0.961147
# b    0.794980
# c    0.530552
# d    0.935127
# Name: series, dtype: float64

# %%
series = pd.Series(3*np.random.rand(4), index= ['a','b','c','d'], name='series')
series
# Out:
# a    0.340972
# b    2.977112
# c    1.917314
# d    1.238512
# Name: series, dtype: float64

# %%
series.plot.pie()
# Out:
# <AxesSubplot:ylabel='series'>

# %%
series.plot.pie(figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='series'>

# %%
series.plot.pie(labels=['AA','BB','CC','DD'], colors=['r','g','b','c'], autopct='%.2f',fontsize=20,figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='series'>

# %%
df = pd.DataFrame({'mass':[0.330,4.87,5.97],'radius':[2439.7,6051.8,6378.1]},index=['Mercury','Venus','Earth'])
df
# Out:
#          mass  radius
# Mercury  0.33  2439.7
# Venus    4.87  6051.8
# Earth    5.97  6378.1

# %%
df_m = df.mass
plot = df_m.plot.pie(figsize=(10,5))

# %%
plot = df.plot.pie(subplots=True,figsize=(10,5))

# %% [markdown]
# - kde

# %%
from pandas.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000,4), columns=['a','b','c','d'])
df.head()
# Out:
#           a         b         c         d
# 0  0.987699  0.006025  0.336501  0.336419
# 1 -0.469866 -0.341169  1.974574 -0.039898
# 2  2.623920  0.824958  0.135511  0.525979
# 3  1.022280  0.030407  0.867026 -1.970357
# 4  0.727309  0.380203 -1.033634 -0.281559

# %%
scatter_matrix(df, alpha=0.2, figsize=(6,6), diagonal='kde') # 대각선에 kde 그래프 그리기
# Out:
# array([[<AxesSubplot:xlabel='a', ylabel='a'>,
#         <AxesSubplot:xlabel='b', ylabel='a'>,
#         <AxesSubplot:xlabel='c', ylabel='a'>,
#         <AxesSubplot:xlabel='d', ylabel='a'>],
#        [<AxesSubplot:xlabel='a', ylabel='b'>,
#         <AxesSubplot:xlabel='b', ylabel='b'>,
#         <AxesSubplot:xlabel='c', ylabel='b'>,
#         <AxesSubplot:xlabel='d', ylabel='b'>],
#        [<AxesSubplot:xlabel='a', ylabel='c'>,
#         <AxesSubplot:xlabel='b', ylabel='c'>,
#         <AxesSubplot:xlabel='c', ylabel='c'>,
#         <AxesSubplot:xlabel='d', ylabel='c'>],
#        [<AxesSubplot:xlabel='a', ylabel='d'>,
#         <AxesSubplot:xlabel='b', ylabel='d'>,
#         <AxesSubplot:xlabel='c', ylabel='d'>,
#         <AxesSubplot:xlabel='d', ylabel='d'>]], dtype=object)

# %%
ser = pd.Series(np.random.randn(1000))
ser.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ser.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
ser.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>
